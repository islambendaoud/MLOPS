# %%
import mlflow

# %% [markdown]
# ### Connecting

# %%
mlflow.sklearn.autolog(log_datasets = False )
mlflow.set_tracking_uri("http://127.0.0.1:5000")
mlflow.set_experiment("model_design_3")
# Out:
# <Experiment: artifact_location='mlflow-artifacts:/864443857530066018', creation_time=1699977548211, experiment_id='864443857530066018', last_update_time=1699977548211, lifecycle_stage='active', name='model_design_3', tags={}>

# %% [markdown]
# ### Build model function

# %%
def build_model(
    dataset,
    dataset_valid,
    pipeline,
    mlflow_run_tags=None,
    mlflow_run_parameters=None,
    mlflow_run_description=None,
):
    """
    Build a sentiment analysis model, print the evaluation result and store everything to MLFlow
    @param: dataset: pandas dataframe containing the input training set
    @param: pipeline: scikit-learn pipeline that will be applied to the input data
    @param: model_name: name of the model as it will be stored in MLFlow
    @param: mlflow_run_tags: dict of tags that will be stored in the MLFlow run
    @param: mlflow_run_parameters: dict of parameters that will be stored in the MLFlow run
    @param: mlflow_run_description: textual description of the run
    @param: mlflow_model_tags: dict of tags that will be stored in the MLFlow registered model
    @param: mlflow_model_description: textual description of the model    
    @return: the ModelInfo of the model generated by MLFlow  
    """
    with mlflow.start_run( description=mlflow_run_description if mlflow_run_description is not None else "") : 
        if mlflow_run_tags is not None:
            for key in mlflow_run_tags.keys():
                mlflow.set_tag(key, mlflow_run_tags[key])
        if mlflow_run_parameters is not None:
            for key in mlflow_run_parameters.keys():
                mlflow.log_param(key, mlflow_run_parameters[key])  

        pipeline.fit(dataset["review"] , dataset['polarity'])

        
        X_valid = dataset_valid["review"]
        y_valid = dataset_valid['polarity']
        y_pred = pipeline.predict(X_valid)


    return pipeline

# %%
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from spacy.lang.fr.stop_words import STOP_WORDS as stopwords
from sklearn.linear_model import LogisticRegression
import pandas as pd

# %% [markdown]
# ## First pipeline

# %%
stopwords = list(stopwords)


pipe = Pipeline([ ("tfidf",TfidfVectorizer(stop_words = stopwords)),("log",LogisticRegression(max_iter = 2000))])

# %% [markdown]
# ### Data loading

# %%
df_t = pd.read_csv("../data/train.csv")
df_v = pd.read_csv("../data/valid.csv")

# %%
build_model(df_t , df_v ,pipe , mlflow_run_tags = {"model_type" : "logistic regression" , "model_version" : "v1"} , mlflow_run_parameters= {"max_iter" : 2000} , mlflow_run_description = "model 3 to try the function build_model")
# Out:
# /Users/islambendaoud/opt/anaconda3/lib/python3.8/site-packages/sklearn/feature_extraction/text.py:408: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['neuf', 'qu', 'quelqu'] not in stop_words.
#   warnings.warn(
# 2023/11/23 11:59:46 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/islambendaoud/opt/anaconda3/lib/python3.8/site-packages/_distutils_hack/__init__.py:33: UserWarning: Setuptools is replacing distutils."
# Pipeline(steps=[('tfidf',
#                  TfidfVectorizer(stop_words=['jusqu', 'douzième', 'quarante',
#                                              'duquel', 'antérieur', 'suivant',
#                                              'nous-mêmes', 'nôtre', 'longtemps',
#                                              'revoilà', 'ceux-ci', 'je',
#                                              'suivantes', 'septième', 'il',
#                                              'envers', 'tant', 'néanmoins',
#                                              'precisement', 'pourrait', 'vé',
#                                              'sept', 'reste', 'étaient',
#                                              'huitième', 'cinquantaine',
#                                              'lesquels', 'bas', 'mes', 'mienne', ...])),
#                 ('log', LogisticRegression(max_iter=2000))])

# %% [markdown]
# ## Second pipeline :
#
# this pipeline is used to see and test the difference in the mlflow side.

# %%
pipe2 = Pipeline([ ("tfidf",TfidfVectorizer(stop_words = stopwords)),("log",LogisticRegression(max_iter = 1300))])
build_model(df_t , df_v ,pipe2 , mlflow_run_tags = {"model_version" : "v1"}  , mlflow_run_description = "model 3 to try second time the function build_model")
# Out:
# /Users/islambendaoud/opt/anaconda3/lib/python3.8/site-packages/sklearn/feature_extraction/text.py:408: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['neuf', 'qu', 'quelqu'] not in stop_words.
#   warnings.warn(
# Pipeline(steps=[('tfidf',
#                  TfidfVectorizer(stop_words=['jusqu', 'douzième', 'quarante',
#                                              'duquel', 'antérieur', 'suivant',
#                                              'nous-mêmes', 'nôtre', 'longtemps',
#                                              'revoilà', 'ceux-ci', 'je',
#                                              'suivantes', 'septième', 'il',
#                                              'envers', 'tant', 'néanmoins',
#                                              'precisement', 'pourrait', 'vé',
#                                              'sept', 'reste', 'étaient',
#                                              'huitième', 'cinquantaine',
#                                              'lesquels', 'bas', 'mes', 'mienne', ...])),
#                 ('log', LogisticRegression(max_iter=1300))])

# %% [markdown]
# **As we tested before , the function build model works perfectly in mlflow. And the result are as waited.**

# %% [markdown]
# # Hyperopt And Mlflow

# %%
from sklearn.metrics import accuracy_score
from spacy.lang.fr.stop_words import STOP_WORDS as stopwords

# %%
stopwords = list(stopwords)

# apply it in the df  
tfidf = TfidfVectorizer(stop_words = stopwords ) 

X = tfidf.fit_transform(df_t["review"])
X_valid = tfidf.transform(df_v["review"])
y = df_t["polarity"]
y_valid = df_v["polarity"]
# Out:
# /Users/islambendaoud/opt/anaconda3/lib/python3.8/site-packages/sklearn/feature_extraction/text.py:408: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['neuf', 'qu', 'quelqu'] not in stop_words.
#   warnings.warn(

# %%
from hyperopt import hp, fmin, tpe, STATUS_OK, Trials

space = {
    'C': hp.uniform('C', 0.1, 10),
    'penalty': hp.choice('penalty', ['l2' , 'l1' ])
}




# define the objective function
def objective(params):
    with mlflow.start_run( ) : 
        params = {'C': params['C'], 'penalty': params['penalty'] }
        model = LogisticRegression(**params,max_iter = 2000  , solver = "liblinear")
        pipe = Pipeline([ ("tfidf",tfidf),("model" ,model)])
        pipe.fit(df_t["review"] , df_t["polarity"] )
        y_pred = pipe.predict(df_v["review"])
        score = accuracy_score(df_v["polarity"],y_pred)
        loss = 1 - score
        mlflow.set_tag("hyperopt_candidate" , True )
    return loss

# start the trials to find the best hyperparameters
trials = Trials()
best = fmin(fn=objective,
            space=space,
            algo=tpe.suggest,
            max_evals=20,
            trials=trials)
# Out:
#   0%|          | 0/20 [00:00<?, ?trial/s, best loss=?]
#  90%|█████████ | 18/20 [2:35:49<17:18, 519.41s/trial, best loss: 0.08040000000000003]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-d799a5fbc546> in <module>
#      24 # start the trials to find the best hyperparameters
#      25 trials = Trials()
# ---> 26 best = fmin(fn=objective,
#      27             space=space,
#      28             algo=tpe.suggest,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/hyperopt/fmin.py in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     538
#     539     if allow_trials_fmin and hasattr(trials, "fmin"):
# --> 540         return trials.fmin(
#     541             fn,
#     542             space,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/hyperopt/base.py in fmin(self, fn, space, algo, max_evals, timeout, loss_threshold, max_queue_len, rstate, verbose, pass_expr_memo_ctrl, catch_eval_exceptions, return_argmin, show_progressbar, early_stop_fn, trials_save_file)
#     669         from .fmin import fmin
#     670
# --> 671         return fmin(
#     672             fn,
#     673             space,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/hyperopt/fmin.py in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     584
#     585     # next line is where the fmin is actually executed
# --> 586     rval.exhaust()
#     587
#     588     if return_argmin:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/hyperopt/fmin.py in exhaust(self)
#     362     def exhaust(self):
#     363         n_done = len(self.trials)
# --> 364         self.run(self.max_evals - n_done, block_until_done=self.asynchronous)
#     365         self.trials.refresh()
#     366         return self
#
# ~/opt/anaconda3/lib/python3.8/site-packages/hyperopt/fmin.py in run(self, N, block_until_done)
#     298                 else:
#     299                     # -- loop over trials and do the jobs directly
# --> 300                     self.serial_evaluate()
#     301
#     302                 self.trials.refresh()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/hyperopt/fmin.py in serial_evaluate(self, N)
#     176                 ctrl = base.Ctrl(self.trials, current_trial=trial)
#     177                 try:
# --> 178                     result = self.domain.evaluate(spec, ctrl)
#     179                 except Exception as e:
#     180                     logger.error("job exception: %s" % str(e))
#
# ~/opt/anaconda3/lib/python3.8/site-packages/hyperopt/base.py in evaluate(self, config, ctrl, attach_attachments)
#     890                 print_node_on_error=self.rec_eval_print_node_on_error,
#     891             )
# --> 892             rval = self.fn(pyll_rval)
#     893
#     894         if isinstance(rval, (float, int, np.number)):
#
# <ipython-input-25-d799a5fbc546> in objective(params)
#      15         model = LogisticRegression(**params,max_iter = 2000  , solver = "liblinear")
#      16         pipe = Pipeline([ ("tfidf",tfidf),("model" ,model)])
# ---> 17         pipe.fit(df_t["review"] , df_t["polarity"] )
#      18         y_pred = pipe.predict(df_v["review"])
#      19         score = accuracy_score(df_v["polarity"],y_pred)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/mlflow/utils/autologging_utils/safety.py in safe_patch_function(*args, **kwargs)
#     569                         patch_function.call(call_original, *args, **kwargs)
#     570                     else:
# --> 571                         patch_function(call_original, *args, **kwargs)
#     572
#     573                     session.state = "succeeded"
#
# ~/opt/anaconda3/lib/python3.8/site-packages/mlflow/utils/autologging_utils/safety.py in patch_with_managed_run(original, *args, **kwargs)
#     248
#     249             try:
# --> 250                 result = patch_function(original, *args, **kwargs)
#     251             except (Exception, KeyboardInterrupt):
#     252                 # In addition to standard Python exceptions, handle keyboard interrupts to ensure
#
# ~/opt/anaconda3/lib/python3.8/site-packages/mlflow/sklearn/__init__.py in patched_fit(fit_impl, allow_children_patch, original, self, *args, **kwargs)
#    1630                 # so we need temporarily disable the post_training_metrics patching.
#    1631                 with _AUTOLOGGING_METRICS_MANAGER.disable_log_post_training_metrics():
# -> 1632                     result = fit_impl(original, self, *args, **kwargs)
#    1633                 if should_log_post_training_metrics:
#    1634                     _AUTOLOGGING_METRICS_MANAGER.register_model(
#
# ~/opt/anaconda3/lib/python3.8/site-packages/mlflow/sklearn/__init__.py in fit_mlflow(original, self, *args, **kwargs)
#    1406         params_logging_future = autologging_client.flush(synchronous=False)
#    1407         fit_output = original(self, *args, **kwargs)
# -> 1408         _log_posttraining_metadata(autologging_client, self, X, y_true, sample_weight)
#    1409         autologging_client.flush(synchronous=True)
#    1410         params_logging_future.await_completion()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/mlflow/sklearn/__init__.py in _log_posttraining_metadata(autologging_client, estimator, X, y, sample_weight)
#    1539                 FLAVOR_NAME, "registered_model_name", None
#    1540             )
# -> 1541             _log_model_with_except_handling(
#    1542                 estimator,
#    1543                 artifact_path="model",
#
# ~/opt/anaconda3/lib/python3.8/site-packages/mlflow/sklearn/__init__.py in _log_model_with_except_handling(*args, **kwargs)
#    1523         def _log_model_with_except_handling(*args, **kwargs):
#    1524             try:
# -> 1525                 return log_model(*args, **kwargs)
#    1526             except _SklearnCustomModelPicklingError as e:
#    1527                 _logger.warning(str(e))
#
# ~/opt/anaconda3/lib/python3.8/site-packages/mlflow/sklearn/__init__.py in log_model(sk_model, artifact_path, conda_env, code_paths, serialization_format, registered_model_name, signature, input_example, await_registration_for, pip_requirements, extra_pip_requirements, pyfunc_predict_fn, metadata)
#     409
#     410     """
# --> 411     return Model.log(
#     412         artifact_path=artifact_path,
#     413         flavor=mlflow.sklearn,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/mlflow/models/model.py in log(cls, artifact_path, flavor, registered_model_name, await_registration_for, metadata, **kwargs)
#     617             ):
#     618                 _logger.warning(_LOG_MODEL_MISSING_SIGNATURE_WARNING)
# --> 619             flavor.save_model(path=local_path, mlflow_model=mlflow_model, **kwargs)
#     620             mlflow.tracking.fluent.log_artifacts(local_path, mlflow_model.artifact_path)
#     621             try:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/mlflow/sklearn/__init__.py in save_model(sk_model, path, conda_env, code_paths, mlflow_model, serialization_format, signature, input_example, pip_requirements, extra_pip_requirements, pyfunc_predict_fn, metadata)
#     300             # To ensure `_load_pyfunc` can successfully load the model during the dependency
#     301             # inference, `mlflow_model.save` must be called beforehand to save an MLmodel file.
# --> 302             inferred_reqs = mlflow.models.infer_pip_requirements(
#     303                 model_data_path,
#     304                 FLAVOR_NAME,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/mlflow/utils/environment.py in infer_pip_requirements(model_uri, flavor, fallback)
#     388     """
#     389     try:
# --> 390         return _infer_requirements(model_uri, flavor)
#     391     except Exception:
#     392         if fallback is not None:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/mlflow/utils/requirements_utils.py in _infer_requirements(model_uri, flavor)
#     408         _PYPI_PACKAGE_INDEX = _load_pypi_package_index()
#     409
# --> 410     modules = _capture_imported_modules(model_uri, flavor)
#     411     packages = _flatten([_MODULES_TO_PACKAGES.get(module, []) for module in modules])
#     412     packages = map(_normalize_package_name, packages)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/mlflow/utils/requirements_utils.py in _capture_imported_modules(model_uri, flavor)
#     305         from mlflow.utils import _capture_modules
#     306
# --> 307         _run_command(
#     308             [
#     309                 sys.executable,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/mlflow/utils/requirements_utils.py in _run_command(cmd, timeout_seconds, env)
#     197     Runs the specified command. If it exits with non-zero status, `MlflowException` is raised.
#     198     """
# --> 199     proc = subprocess.Popen(cmd, stdout=subprocess.PIPE, stderr=subprocess.PIPE, env=env)
#     200     timer = Timer(timeout_seconds, proc.kill)
#     201     try:
#
# ~/opt/anaconda3/lib/python3.8/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     856                             encoding=encoding, errors=errors)
#     857
# --> 858             self._execute_child(args, executable, preexec_fn, close_fds,
#     859                                 pass_fds, cwd, env,
#     860                                 startupinfo, creationflags, shell,
#
# ~/opt/anaconda3/lib/python3.8/subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, start_new_session)
#    1660                 errpipe_data = bytearray()
#    1661                 while True:
# -> 1662                     part = os.read(errpipe_read, 50000)
#    1663                     errpipe_data += part
#    1664                     if not part or len(errpipe_data) > 50000:
#
# KeyboardInterrupt:

# %%
print(best)
# Out:
# {'C': 5.318920759871554, 'penalty': 0}

# %%
with mlflow.start_run( ) : 
    params = {'C': best['C']}
    model = LogisticRegression(**params,max_iter = 2000  , solver = "liblinear")
    pipe = Pipeline([ ("tfidf",TfidfVectorizer(stop_words = stopwords)),("model" ,model)])
    pipe.fit(df_t["review"] , df_t["polarity"] )
    y_pred = pipe.predict(df_v["review"])
    mlflow.set_tag("hyperopt_selected_new" , True)
    mlflow.sklearn.log_model(pipe , "model_3_hyperopt_new" , registered_model_name = "model_3_hyperopt")
# Out:
# /Users/islambendaoud/opt/anaconda3/lib/python3.8/site-packages/sklearn/feature_extraction/text.py:408: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['neuf', 'qu', 'quelqu'] not in stop_words.
#   warnings.warn(
# Registered model 'model_3_hyperopt' already exists. Creating a new version of this model...
# 2023/11/21 15:32:34 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: model_3_hyperopt, version 2
# Created version '2' of model 'model_3_hyperopt'.
